# %% [markdown]
# >>>>>                                                                       STUDENTS PERFORMANCE PROJECT.

# %% [markdown]
#                                                                     IMPORTING THE BASIC LIBRARIES AND LOADING THE DATA.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
#warnings.filterwarnings("ignore")

# %%
data = pd.read_csv(r'D:\Portfolio Manager\My start\1\PROJECTS\STUDENTS PERFORMANCE\StudentsPerformance.csv')
d = data.copy()
data
# Out:
#      Gender Race/Ethnicity Parental Level of Education         Lunch  \
# 0    female        group C            Some High School  free/reduced
# 1    female        group B                 High School  free/reduced
# 2    female        group B            Some High School  free/reduced
# 3    female        group B                Some College      standard
# 4    female        group C                Some College  free/reduced
# ..      ...            ...                         ...           ...
# 995    male        group E                Some College      standard
# 996    male        group A                Some College      standard
# 997    male        group D                Some College      standard
# 998    male        group E          Associate's Degree  free/reduced
# 999    male        group E           Bachelor's Degree      standard
#
#     Test Preparation Course  Math Score  Reading Score  Writing Score
# ...

# %% [markdown]
#                                                                 EXPLORATORY DATA ANALYSIS/ DATA UNDERSTANDING.

# %%
print('-> Data Informations:-')
data.info()
print()
print('-> Data(Observations, Features):-' , data.shape)
print()
print('-> Total Size of the Dataset is:-' , data.size)
print()
print('-> Stat Summary of Data:-' '\n', data.describe())
# Out:
# -> Data Informations:-
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Gender                       1000 non-null   object
#  1   Race/Ethnicity               1000 non-null   object
#  2   Parental Level of Education  1000 non-null   object
#  3   Lunch                        1000 non-null   object
#  4   Test Preparation Course      1000 non-null   object
#  5   Math Score                   1000 non-null   int64
#  6   Reading Score                1000 non-null   int64
#  7   Writing Score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB
#
# -> Data(Observations, Features):- (1000, 8)
#
# -> Total Size of the Dataset is:- 8000
#
# -> Stat Summary of Data:-
#          Math Score  Reading Score  Writing Score
# count  1000.000000    1000.000000    1000.000000
# ...

# %%
data.head()
# Out:
#    Gender Race/Ethnicity Parental Level of Education         Lunch  \
# 0  female        group C            Some High School  free/reduced
# 1  female        group B                 High School  free/reduced
# 2  female        group B            Some High School  free/reduced
# 3  female        group B                Some College      standard
# 4  female        group C                Some College  free/reduced
#
#   Test Preparation Course  Math Score  Reading Score  Writing Score
# 0                    none           0             17             10
# 1                    none           8             24             23
# 2                    none          18             32             28
# 3                    none          11             38             32
# 4                    none          22             39             33

# %%
print('-> Number of Duplicates if any;''\n', data.duplicated().value_counts())
print()
print('-> Number of Unique Values of Data-Points;''\n',data.nunique())
print()
print('-> Number of Missing Values if any ;' '\n', data.isna().sum())
print()
print('-> Data Types;''\n', data.dtypes)
# Out:
# -> Number of Duplicates if any;
#  False    1000
# dtype: int64
#
# -> Number of Unique Values of Data-Points;
#  Gender                          2
# Race/Ethnicity                  5
# Parental Level of Education     6
# Lunch                           2
# Test Preparation Course         2
# Math Score                     85
# Reading Score                  72
# Writing Score                  77
# dtype: int64
#
# -> Number of Missing Values if any ;
#  Gender                         0
# Race/Ethnicity                 0
# Parental Level of Education    0
# Lunch                          0
# Test Preparation Course        0
# Math Score                     0
# Reading Score                  0
# Writing Score                  0
# dtype: int64
#
# -> Data Types;
#  Gender                         object
# Race/Ethnicity                 object
# Parental Level of Education    object
# Lunch                          object
# Test Preparation Course        object
# ...

# %% [markdown]
# >    "INSIGHT 1:" Gender | Race/Ethnicity | Parental Level of Education | Lunch | Test Preparation Course Feature Variables are Categorical-Object Data Type Variables, whereas Math Score | Reading Score | Writing Score are Discrete-Numerical Data Type Variables.

# %% [markdown]
#     --> UNIVARIATE ANALYSIS.

# %%
plt.figure(figsize=(28,12))
sns.boxplot(data = data, orient = 'h' )
plt.title('OUTLIERS OF NUMERICAL DATA VARIABLES.', fontdict = {'family': 'Verdana', 'color':  'darkblue', 'style':'italic', 'size':'24'})
plt.xlabel('Data-point Values ------------------->')
plt.ylabel('FEATURE/ ATTRIBUTES ------------------->')
plt.grid()

# %%
data.columns
# Out:
# Index(['Gender', 'Race/Ethnicity', 'Parental Level of Education', 'Lunch',
#        'Test Preparation Course', 'Math Score', 'Reading Score',
#        'Writing Score'],
#       dtype='object')

# %%
# Categorical Variables are stored in 'cat' dataframe.
cat = data[['Gender', 'Race/Ethnicity', 'Parental Level of Education', 'Lunch', 'Test Preparation Course']]

# Discrete Numerical Variables are stored in 'dis' dataframe.
dis = data[['Math Score', 'Reading Score', 'Writing Score']]

# %%
for i in dis:
    sns.displot(data = dis, x = dis[i], kde = True)
    plt.grid()

# %%
cat.columns
# Out:
# Index(['Gender', 'Race/Ethnicity', 'Parental Level of Education', 'Lunch',
#        'Test Preparation Course'],
#       dtype='object')

# %%
for i in cat:
    plt.figure(figsize=(15,6))
    sns.countplot(data = cat, x = cat[i])
    plt.grid()

# %% [markdown]
#     --> BIVARIATE ANALYSIS.

# %%
plt.subplots(figsize= (27,9))
sns.heatmap(dis.corr(), cbar= True, linecolor= 'orange', linewidths=1.5, cmap='PRGn_r', vmin = 0.5, annot = True, fmt='.2%', cbar_kws = {"shrink":.8, 'extend':'both'})
plt.title('Plotted for understanding the Relation between the Feature Attributes and the Target Attribute.', fontdict = {'family': 'Verdana', 'color':  'red', 'style':'italic', 'size':'24'})
plt.xlabel('FEATURE/ ATTRIBUTES ------------------->')
plt.ylabel('FEATURE/ ATTRIBUTES ------------------->')
plt.xticks(rotation = 16)
plt.yticks(rotation = 2)
plt.show()

# %%
cat.columns
# Out:
# Index(['Gender', 'Race/Ethnicity', 'Parental Level of Education', 'Lunch',
#        'Test Preparation Course'],
#       dtype='object')

# %%
for i in dis:
    plt.figure(figsize=(15,6))
    sns.histplot(data = dis, x = dis[i], kde = True, hue = cat['Gender'])
    plt.grid()

# %%
for i in dis: 
    plt.figure(figsize=(15,6))
    sns.histplot(data = dis, x = dis[i], kde = True, hue = cat['Lunch'])
    plt.grid()

# %%
for i in dis:
    plt.figure(figsize=(15,6))
    sns.histplot(data = dis, x = dis[i], kde = True, hue = cat['Parental Level of Education'])
    plt.grid()

# %%
for i in dis:
    plt.figure(figsize=(15,6))
    sns.histplot(data = dis, x = dis[i], kde = True, hue = cat['Race/Ethnicity'])
    plt.grid()

# %%
for i in dis:
    plt.figure(figsize=(15,6))
    sns.histplot(data = dis, x = dis[i], kde = True, hue = cat['Test Preparation Course'])
    plt.grid()

# %% [markdown]
#                                                                                 FEATURE ENGIEERING.

# %%
dis['Aggregate Mark']=((dis['Math Score'] + dis['Reading Score'] + dis['Writing Score']))
dis.head()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_6452\3843235910.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dis['Aggregate Mark']=((dis['Math Score'] + dis['Reading Score'] + dis['Writing Score']))
#    Math Score  Reading Score  Writing Score  Aggregate Mark
# 0           0             17             10              27
# 1           8             24             23              55
# 2          18             32             28              78
# 3          11             38             32              81
# 4          22             39             33              94

# %%
plt.figure(figsize=(15,6))
sns.barplot(x = cat['Gender'], y = dis['Aggregate Mark'])
plt.xticks(rotation = 60)
plt.ylim(0, 300)
plt.axhline(y = dis['Aggregate Mark'].mean(), color = 'grey', linestyle = 'dashdot', label = "Mean Line")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.barplot(x = cat['Race/Ethnicity'], y = dis['Aggregate Mark'])
plt.xticks(rotation = 60)
plt.ylim(0, 300)
plt.axhline(y = dis['Aggregate Mark'].mean(), color = 'grey', linestyle = 'dashdot', label = "Mean Line")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.barplot(x = cat['Parental Level of Education'], y = dis['Aggregate Mark'])
plt.xticks(rotation = 60)
plt.ylim(0, 300)
plt.axhline(y = dis['Aggregate Mark'].mean(), color = 'grey', linestyle = 'dashdot', label = "Mean Line")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.barplot(x = cat['Lunch'], y = dis['Aggregate Mark'])
plt.xticks(rotation = 60)
plt.ylim(0, 300)
plt.axhline(y = dis['Aggregate Mark'].mean(), color = 'grey', linestyle = 'dashdot', label = "Mean Line")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.barplot(x = cat['Test Preparation Course'], y = dis['Aggregate Mark'])
plt.xticks(rotation = 60)
plt.ylim(0, 300)
plt.axhline(y = dis['Aggregate Mark'].mean(), color = 'grey', linestyle = 'dashdot', label = "Mean Line")
plt.legend()
plt.show()

# %% [markdown]
# >    "INSIGHT 2:" (i) Female Students have higher Aggregate Mark than the Male Students.
#                 (ii) Group E (Race/ Ethnicity) Students have higher Aggregate Mark among the other Groups and Group A have the lowest Aggregate Mark.
#                (iii) Students whose Parental Level of Education: "Master's Degree" have higher Aggregate Mark whereas those students whose Parental Level of Education: "High School" have the lowest Aggregate Mark.
#                 (iv) Students under "Standard Meals" criteria have higher Aggregate Mark than those "Free/ Reduced" Students.
#                  (v) Students whoever " Completed: Test Preparation Course" have higher Aggregate Mark.
#
# * NOTE 1: The Above Insight based only on Aggregate Score(Math + Reading + Writing).

# %%
plt.figure(figsize = (18, 9))

plt.subplot(131)
plt.title('MATHS SCORE')
sns.barplot(x = cat['Test Preparation Course'], y = dis['Math Score'], hue = cat['Gender'])
plt.axhline(y = dis['Math Score'].mean(), color = 'grey', linestyle = 'dashdot', label = "Avg Maths Score")
plt.legend()
plt.grid()

plt.subplot(132)
plt.title('READING SCORE')
sns.barplot(x = cat['Test Preparation Course'], y = dis['Reading Score'], hue = cat['Gender'])
plt.axhline(y = dis['Reading Score'].mean(), color = 'grey', linestyle = 'dashdot', label = "Avg Reading Score")
plt.legend()
plt.grid()

plt.subplot(133)
plt.title('WRITING SCORE')
sns.barplot(x = cat['Test Preparation Course'], y = dis['Writing Score'], hue = cat['Gender'])
plt.axhline(y = dis['Writing Score'].mean(), color = 'grey', linestyle = 'dashdot', label = "Avg Writing Score")
plt.legend()
plt.grid()

plt.show()

# %% [markdown]
# >    "INSIGHT 3:" (i) MATHS SCORE - "Male" Students scores "more" marks in "Mathematics" than "Female" Students, even if they "have Completed" or "Not Taken" the "Test Preparation Course".
#                 (ii) READING SCORE - "Female" Students scores "more" marks in "Reading" than "Male" Students, even if they "have Completed" or "Not Taken" the "Test Preparation Course".
#                 (iv) WRITING SCORE - "Female" Students scores "more" marks in "Writing" than "Male" Students, even if they "have Completed" or "Not Taken" the "Test Preparation Course".
