# %% [markdown]
# >>>>>                                                                                  IRIS SPECIES PROJECT.

# %% [markdown]
#                                                                            IMPORTING THE BASIC LIBRARIES AND LOADING THE DATA.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
#warnings.filterwarnings("ignore")

# %%
data = pd.read_csv(r'D:\Portfolio Manager\My start\1\PROJECTS\IRIS SPECIES\iris.csv')
d = data.copy()
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
#                                                                             EXPLORATORY DATA ANALYSIS/ DATA UNDERSTANDING.

# %%
print('-> Data Informations:-')
data.info()
print()
print('-> Data(Observations, Features):-' , data.shape)
print()
print('-> Total Size of the Dataset is:-' , data.size)
print()
print('-> Stat Summary of Data:-' '\n', data.describe())
# Out:
# -> Data Informations:-
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB
#
# -> Data(Observations, Features):- (150, 5)
#
# -> Total Size of the Dataset is:- 750
#
# -> Stat Summary of Data:-
#         sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# ...

# %%
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
print('-> Number of Duplicates if any;''\n', data.duplicated().value_counts())
print()
print('-> Number of Unique Values of Data-Points;''\n',data.nunique())
print()
print('-> Number of Missing Values if any ;' '\n', data.isna().sum())
print()
print('-> Data Types;''\n', data.dtypes)
# Out:
# -> Number of Duplicates if any;
#  False    147
# True       3
# dtype: int64
#
# -> Number of Unique Values of Data-Points;
#  sepal_length    35
# sepal_width     23
# petal_length    43
# petal_width     22
# species          3
# dtype: int64
#
# -> Number of Missing Values if any ;
#  sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64
#
# -> Data Types;
#  sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
data.drop_duplicates(inplace = True, ignore_index = True)
data.species.unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %% [markdown]
#     "INSIGHT 1": Values under the features/ attributes; 'Sepal Length', 'Sepal Width', 'Petal Lenght' & 'Petal Width' are Continuous Float-DType Variables and the values under Species feature are Categorical Object-DType Variables.

# %% [markdown]
#     --> UNIVARIATE ANALYSIS.

# %%
plt.figure(figsize=(28,12))
sns.boxplot(data = data, orient = 'h' )
plt.title('OUTLIERS OF NUMERICAL DATA VARIABLES.', fontdict = {'family': 'Verdana', 'color':  'darkblue', 'style':'italic', 'size':'24'})
plt.xlabel('Data-point Values ------------------->')
plt.ylabel('FEATURE/ ATTRIBUTES ------------------->')
plt.grid()

# %%
for i in data:
    sns.displot(data = data, x = data[i], kde = True)
    plt.grid()

# %%
count = data.species.value_counts()
count.plot(kind = 'bar', rot = 0)
plt.title('SPECIES DISTRIBUTION')
plt.xlabel('Types of Iris Species ------> ')
plt.ylabel('Value Points ------> ')
plt.grid()

# %% [markdown]
#     "INSIGHT 2": After Univariate Analysis of our data variables it is conveyed that; the Categorical Variable feature 'Species' is not that much imbalanced as it is 50|49|48, also there are some outliers in Sepal Width along both the positive and negative direction and there is a skewness in Continuous Variables feature's distribution- Petal Length and Petal Width.

# %% [markdown]
#     --> BIVARIATE ANALYSIS.

# %%
plt.subplots(figsize= (27,9))
sns.heatmap(data.corr(), cbar= True, linecolor= 'orange', linewidths=1.5, cmap='PRGn_r', annot = True, fmt='.2%', cbar_kws = {"shrink":.8, 'extend':'both'})
plt.title('Plotted for understanding the Relation between the Feature Attributes and the Target Attribute.', fontdict = {'family': 'Verdana', 'color':  'red', 'style':'italic', 'size':'24'})
plt.xlabel('FEATURE/ ATTRIBUTES ------------------->')
plt.ylabel('FEATURE/ ATTRIBUTES ------------------->')
plt.xticks(rotation = 16)
plt.yticks(rotation = 2)
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_13796\1870559391.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr(), cbar= True, linecolor= 'orange', linewidths=1.5, cmap='PRGn_r', annot = True, fmt='.2%', cbar_kws = {"shrink":.8, 'extend':'both'})

# %%
for i in data:
    sns.set_palette('bright', color_codes = True, n_colors = 6) 
    plt.figure(figsize=(15,6))
    sns.histplot(x = data[i], data = data, kde = True, hue = data.species)
    plt.grid()

# %% [markdown]
#     "INSIGHT 3": About the correlation; There is a "Very High Correlation" of -> 'Sepal Length with Petal Length|Petal Width', 'Petal Length with Petal Width|Sepal Length' & 'Petal Width with Petal Length|Sepal Length' and a Very Low Correlation of -> 'Sepal Length with Sepal Width', 'Sepal Width with Sepal Length|Petal Width|Petal Length', 'Petal Length with Sepal Width' & Petal Width with Sepal Width'.

# %%
insight_4 = pd.read_excel(r'D:\Portfolio Manager\My start\1\PROJECTS\IRIS SPECIES\Insight_4.xlsx')
insight_4
# Out:
#                     Species Sepal Length (cm) Sepal Width (cm)  \
# 0        IRIS SETOSA (Blue)           4.2 - 6          2 - 4.3
# 1  IRIS VERSICOLOR (Orange)         4.6 - 7.1          2 - 3.5
# 2    IRIS VIRGINICA (Green)           4.6 - 8        2.3 - 3.9
#
#   Petal Length (cm) Petal Width (cm)
# 0           1 - 2.5            0 - 1
# 1         2.9 - 5.7          0.8 - 2
# 2           4.1 - 7        1.1 - 2.5

# %% [markdown]
#     "INSIGHT 4":
#     (i) Iris Setosa -> Sepal shape; length wise it is shorter but wider | Petal Shape; it is much shorter in length as well as in width than the other two species.
#     (ii) Iris Veriscolor -> Sepal shape; length wise it is more when compared with Setosa species but somewhat kind of similar with Virginica species | Petal Shape; in length longer than Setosa but shorter than Virginica species.
#     (iii) Iris Virginica -> This species of Iris Plant is the lengthiest and widest of the three expect for the sepal width which is quite less when compared with Setosa species.

# %% [markdown]
#                                                                                           DATA PRE-PROCESSING.

# %% [markdown]
#     --> MISSING VALUES HANDLING.

# %%
data.isna().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %% [markdown]
# NOTE 1: 'There are no Missing Values in our dataset'.

# %% [markdown]
#     --> OUTLIER MANAGEMENT.

# %%
plt.figure(figsize=(28,12))
sns.boxplot(data = data.sepal_width, orient = 'h' )
plt.title('OUTLIERS IN SEPAL WIDTH ATTRIBUTE(NUMERICAL CONTINUOUS VARIABLE)', fontdict = {'family': 'Verdana', 'color':  'darkred', 'style':'italic', 'size':'24'})
plt.xlabel('Data-point Values ------------------->')
plt.grid()

# %% [markdown]
# NOTE 2: 'With Reference to Insight 2 and the above and blow results are those Outliers in Sepal Width Features'.

# %%
Q1 = np.percentile(data['sepal_width'], 25, interpolation='midpoint')
Q2 = np.percentile(data['sepal_width'], 50, interpolation='midpoint')
Q3 = np.percentile(data['sepal_width'], 75, interpolation='midpoint')
print('Q1 = ',Q1)
print('Q2 = ',Q2)
print('Q3 = ',Q3)
print('Median of Sepal Width =', data.sepal_width.median())
# Out:
# Q1 =  2.8
# Q2 =  3.0
# Q3 =  3.3
# Median of Sepal Width = 3.0

# %%
IQR = Q3 - Q1
print('IQR =', IQR)
low_limit = Q1 - 1.5*IQR
up_limit = Q3 + 1.5*IQR
print('The Lower Fence Value is:', low_limit)
print('The Upper Fence Value is:', up_limit)
# Out:
# IQR = 0.5
# The Lower Fence Value is: 2.05
# The Upper Fence Value is: 4.05

# %%
Outliers = []
for o in data['sepal_width']:
    if((o<low_limit) or (o>up_limit)):
        Outliers.append(o)       
print('Those Sepal Width Outliers are:', Outliers)
# Out:
# Those Sepal Width Outliers are: [4.4, 4.1, 4.2, 2.0]

# %%
data1 = data.copy()
data1.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
for i in data:
    sns.displot(data = data, x = data[i], kde = True)
    plt.grid()

print('SKEWNESS OF DATA BEFORE LOG TRANSFORMATIONS on every Features: ''\n', data.skew())
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_13796\186548816.py:5: FutureWarning: The default value of numeric_only in DataFrame.skew is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   print('SKEWNESS OF DATA BEFORE LOG TRANSFORMATIONS on every Features: ''\n', data.skew())
# SKEWNESS OF DATA BEFORE LOG TRANSFORMATIONS on every Features:
#  sepal_length    0.292560
# sepal_width     0.324351
# petal_length   -0.293763
# petal_width    -0.113479
# dtype: float64

# %% [markdown]
# NOTE 3: 'Since Logisitc Regression Model requires  Normally Distributed Datas; Petal Length & Petal Width Features current distribution has to be changed along with Sepal Width's Outlier Treatment'.

# %%
data1['petal_length'] = data1['petal_length'].apply(np.log10)
data1['sepal_width'] = data1['sepal_width'].apply(np.log10)

print('SKEWNESS OF DATA AFTER LOG TRANSFORMATIONS on Petal Length and Sepal Width: ''\n', data1.skew())

for i in data1:
    sns.displot(data = data1, x = data1[i], kde = True)
    plt.grid()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_13796\4012045855.py:4: FutureWarning: The default value of numeric_only in DataFrame.skew is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   print('SKEWNESS OF DATA AFTER LOG TRANSFORMATIONS on Petal Length and Sepal Width: ''\n', data1.skew())
# SKEWNESS OF DATA AFTER LOG TRANSFORMATIONS on Petal Length and Sepal Width:
#  sepal_length    0.292560
# sepal_width    -0.122806
# petal_length   -0.616413
# petal_width    -0.113479
# dtype: float64

# %% [markdown]
#     --> SCALING.

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
data1.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %% [markdown]
# NOTE 4: 'Scaling is only needed for Continuous Variables hence the needed attributes are sorted under two dataframes "no_scale" & "scale"'.

# %%
no_scale = data1[['sepal_width', 'petal_length', 'species']]
scale = data1[['sepal_length', 'petal_width']]

# %%
scaled = MinMaxScaler(feature_range = (0,1)).fit_transform(scale)
scaled_data = pd.DataFrame(scaled, columns = scale.columns)
scaled_data.head()
# Out:
#    sepal_length  petal_width
# 0      0.222222     0.041667
# 1      0.166667     0.041667
# 2      0.111111     0.041667
# 3      0.083333     0.041667
# 4      0.194444     0.041667

# %%
Data = pd.concat([scaled_data, no_scale], axis = 1)
Data
# Out:
#      sepal_length  petal_width  sepal_width  petal_length         species
# 0        0.222222     0.041667     0.544068      0.146128     Iris-setosa
# 1        0.166667     0.041667     0.477121      0.146128     Iris-setosa
# 2        0.111111     0.041667     0.505150      0.113943     Iris-setosa
# 3        0.083333     0.041667     0.491362      0.176091     Iris-setosa
# 4        0.194444     0.041667     0.556303      0.146128     Iris-setosa
# ..            ...          ...          ...           ...             ...
# 142      0.666667     0.916667     0.477121      0.716003  Iris-virginica
# 143      0.555556     0.750000     0.397940      0.698970  Iris-virginica
# 144      0.611111     0.791667     0.477121      0.716003  Iris-virginica
# 145      0.527778     0.916667     0.531479      0.732394  Iris-virginica
# 146      0.444444     0.708333     0.477121      0.707570  Iris-virginica
#
# [147 rows x 5 columns]

# %% [markdown]
#                                                                                             MODEL BUILDING.

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score, accuracy_score, classification_report

Data.columns
# Out:
# Index(['sepal_length', 'petal_width', 'sepal_width', 'petal_length',
#        'species'],
#       dtype='object')

# %%
# Spliting the Data for Training and Testing the Model 

y = Data['species']
x = Data.drop('species', axis = 1)

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.25)
X_train.head()
# Out:
#     sepal_length  petal_width  sepal_width  petal_length
# 42      0.222222     0.125000     0.579784      0.278754
# 19      0.222222     0.083333     0.579784      0.176091
# 2       0.111111     0.041667     0.505150      0.113943
# 83      0.472222     0.625000     0.531479      0.653213
# 20      0.305556     0.041667     0.531479      0.230449

# %% [markdown]
# > LOGISTIC REGRESSION ML MODEL.

# %%
from sklearn.linear_model import LogisticRegression

log_reg = LogisticRegression(max_iter=165, random_state = 42)
model_lr = log_reg.fit(X_train, y_train)
y_pred_lr = model_lr.predict(X_test)

print('CLASSIFICATION REPORT:', '\n', classification_report(y_test,y_pred_lr ))
print('ACCURACY:', accuracy_score(y_test, y_pred_lr)*100,'%')
print('')
print('CONFUSION MATRIX:')
pd.crosstab(y_test, y_pred_lr, rownames=['True'], colnames=['Predicted'], margins=True)
# Out:
# CLASSIFICATION REPORT:
#                   precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        13
# Iris-versicolor       0.89      1.00      0.94         8
#  Iris-virginica       1.00      0.94      0.97        16
#
#        accuracy                           0.97        37
#       macro avg       0.96      0.98      0.97        37
#    weighted avg       0.98      0.97      0.97        37
#
# ACCURACY: 97.2972972972973 %
#
# CONFUSION MATRIX:
# Predicted        Iris-setosa  Iris-versicolor  Iris-virginica  All
# True
# Iris-setosa               13                0               0   13
# Iris-versicolor            0                8               0    8
# Iris-virginica             0                1              15   16
# All                       13                9              15   37

# %% [markdown]
# > K NEAREST NEIGHBOURS ML MODEL.

# %%
from sklearn.neighbors import KNeighborsClassifier
error_1= []
error_2= []
for k in range(1,20):
    knn= KNeighborsClassifier(n_neighbors=k)
    model1_knn = knn.fit(X_train,y_train)
    y_pred_knn_1= model1_knn.predict(X_train)
    error_1.append(np.mean(y_train!= y_pred_knn_1))
    y_pred_knn_2= model1_knn.predict(X_test)
    error_2.append(np.mean(y_test!= y_pred_knn_2))


plt.plot(range(1,20), error_1, 'o-', label = 'Train Data')
plt.plot(range(1,20), error_2, 'o-', label = 'Test Data')
plt.title('ERROR PLOT')
plt.xlabel('k-Value------->')
plt.ylabel('Error------->')
plt.legend()
plt.grid()

# %%
k_matrix = []
neighbors = np.arange(1, 20)

for k in neighbors:
    knn = KNeighborsClassifier(n_neighbors=k)
    model2_knn = knn.fit(X_train, y_train)
    y_pred2_knn = model2_knn.predict(X_test)
    acc = accuracy_score(y_test,y_pred2_knn)
    k_matrix.append(acc)

plt.plot(neighbors, k_matrix,'o-')
plt.title('ACCURACY PLOT')
plt.xlabel('k-Value------->')
plt.ylabel('Accuracy------->')
plt.grid()

# %% [markdown]
#     NOTE:- From the above Error & Accuracy Plots, it could be concluded that the optimum value of k lies after 10, so "10" is taken as the n_neighbors value for model deployement.

# %%
knn = KNeighborsClassifier(n_neighbors = 10)# by default metric = ’minkowski’.  
knn_model = knn.fit(X_train, y_train)
y_pred_knn = knn_model.predict(X_test)

print('CLASSIFICATION REPORT:', '\n', classification_report(y_test,y_pred_knn))
print('ACCURACY:', accuracy_score(y_test, y_pred_knn)*100,'%')
print('')
print('CONFUSION MATRIX:')
pd.crosstab(y_test, y_pred_knn, rownames=['True'], colnames=['Predicted'], margins=True)
# Out:
# CLASSIFICATION REPORT:
#                   precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        13
# Iris-versicolor       0.89      1.00      0.94         8
#  Iris-virginica       1.00      0.94      0.97        16
#
#        accuracy                           0.97        37
#       macro avg       0.96      0.98      0.97        37
#    weighted avg       0.98      0.97      0.97        37
#
# ACCURACY: 97.2972972972973 %
#
# CONFUSION MATRIX:
# Predicted        Iris-setosa  Iris-versicolor  Iris-virginica  All
# True
# Iris-setosa               13                0               0   13
# Iris-versicolor            0                8               0    8
# Iris-virginica             0                1              15   16
# All                       13                9              15   37

# %%
knn_1 = KNeighborsClassifier(n_neighbors = 10, metric = 'canberra')
knn_model_1 = knn_1.fit(X_train, y_train)
y_pred_knn_1 = knn_model_1.predict(X_test)

print('CLASSIFICATION REPORT:', '\n', classification_report(y_test,y_pred_knn_1))
print('ACCURACY:', accuracy_score(y_test, y_pred_knn_1)*100,'%')
print('')
print('CONFUSION MATRIX:')
pd.crosstab(y_test, y_pred_knn_1, rownames=['True'], colnames=['Predicted'], margins=True)
# Out:
# CLASSIFICATION REPORT:
#                   precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        13
# Iris-versicolor       0.80      1.00      0.89         8
#  Iris-virginica       1.00      0.88      0.93        16
#
#        accuracy                           0.95        37
#       macro avg       0.93      0.96      0.94        37
#    weighted avg       0.96      0.95      0.95        37
#
# ACCURACY: 94.5945945945946 %
#
# CONFUSION MATRIX:
# Predicted        Iris-setosa  Iris-versicolor  Iris-virginica  All
# True
# Iris-setosa               13                0               0   13
# Iris-versicolor            0                8               0    8
# Iris-virginica             0                2              14   16
# All                       13               10              14   37

# %% [markdown]
# >SUPPORT VECTOR MACHINE ML MODELS.

# %% [markdown]
# >>-> LINEAR SVM KERNEL MODEL.

# %%
from sklearn.svm import SVC

svm_clf = SVC(kernel='linear', random_state = 42)
svm_model = svm_clf.fit(X_train, y_train)
y_pred_svm1 = svm_clf.predict(X_test)


print('CLASSIFICATION REPORT:', '\n', classification_report(y_test,y_pred_svm1))
print('ACCURACY:', accuracy_score(y_test, y_pred_svm1)*100,'%')
print('')
print('CONFUSION MATRIX:')
pd.crosstab(y_test, y_pred_svm1, rownames=['True'], colnames=['Predicted'], margins=True)
# Out:
# CLASSIFICATION REPORT:
#                   precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        13
# Iris-versicolor       0.89      1.00      0.94         8
#  Iris-virginica       1.00      0.94      0.97        16
#
#        accuracy                           0.97        37
#       macro avg       0.96      0.98      0.97        37
#    weighted avg       0.98      0.97      0.97        37
#
# ACCURACY: 97.2972972972973 %
#
# CONFUSION MATRIX:
# Predicted        Iris-setosa  Iris-versicolor  Iris-virginica  All
# True
# Iris-setosa               13                0               0   13
# Iris-versicolor            0                8               0    8
# Iris-virginica             0                1              15   16
# All                       13                9              15   37

# %% [markdown]
# >>-> RADIAL BASIS FUNCTION(RBF) SVM KERNEL MODEL.

# %%
svm_clf_rbf = SVC(kernel='rbf', random_state = 42)
svm_model = svm_clf_rbf.fit(X_train, y_train)
y_pred_rbf = svm_clf_rbf.predict(X_test)

print('CLASSIFICATION REPORT:', '\n', classification_report(y_test,y_pred_rbf))
print('ACCURACY:', accuracy_score(y_test, y_pred_rbf)*100,'%')
print('')
print('CONFUSION MATRIX:')
pd.crosstab(y_test, y_pred_rbf, rownames=['True'], colnames=['Predicted'], margins=True)
# Out:
# CLASSIFICATION REPORT:
#                   precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        13
# Iris-versicolor       0.89      1.00      0.94         8
#  Iris-virginica       1.00      0.94      0.97        16
#
#        accuracy                           0.97        37
#       macro avg       0.96      0.98      0.97        37
#    weighted avg       0.98      0.97      0.97        37
#
# ACCURACY: 97.2972972972973 %
#
# CONFUSION MATRIX:
# Predicted        Iris-setosa  Iris-versicolor  Iris-virginica  All
# True
# Iris-setosa               13                0               0   13
# Iris-versicolor            0                8               0    8
# Iris-virginica             0                1              15   16
# All                       13                9              15   37

# %% [markdown]
# >>-> POLYNOMIAL SVM KERNEL MODEL.

# %%
svm_clf_p = SVC(kernel='poly', degree = 2, random_state = 42)
svm_model = svm_clf_p.fit(X_train, y_train)
y_pred_p = svm_clf_p.predict(X_test)

print('CLASSIFICATION REPORT:', '\n', classification_report(y_test,y_pred_p))
print('ACCURACY:', accuracy_score(y_test, y_pred_p)*100,'%')
print('')
print('CONFUSION MATRIX:')
pd.crosstab(y_test, y_pred_p, rownames=['True'], colnames=['Predicted'], margins=True)
# Out:
# CLASSIFICATION REPORT:
#                   precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        13
# Iris-versicolor       0.89      1.00      0.94         8
#  Iris-virginica       1.00      0.94      0.97        16
#
#        accuracy                           0.97        37
#       macro avg       0.96      0.98      0.97        37
#    weighted avg       0.98      0.97      0.97        37
#
# ACCURACY: 97.2972972972973 %
#
# CONFUSION MATRIX:
# Predicted        Iris-setosa  Iris-versicolor  Iris-virginica  All
# True
# Iris-setosa               13                0               0   13
# Iris-versicolor            0                8               0    8
# Iris-virginica             0                1              15   16
# All                       13                9              15   37

# %% [markdown]
# >  DECISION TREE ML MODEL.

# %%
from sklearn.tree import DecisionTreeClassifier

dtm_clf = DecisionTreeClassifier(random_state = 42)
dtm_clf.fit(X_train, y_train)
y_pred_dtm = dtm_clf.predict(X_test)


print('CLASSIFICATION REPORT:', '\n', classification_report(y_test,y_pred_dtm))
print('ACCURACY:', accuracy_score(y_test, y_pred_dtm)*100,'%')
print('')
print('CONFUSION MATRIX:')
pd.crosstab(y_test, y_pred_dtm, rownames=['True'], colnames=['Predicted'], margins=True)
# Out:
# CLASSIFICATION REPORT:
#                   precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        13
# Iris-versicolor       1.00      1.00      1.00         8
#  Iris-virginica       1.00      1.00      1.00        16
#
#        accuracy                           1.00        37
#       macro avg       1.00      1.00      1.00        37
#    weighted avg       1.00      1.00      1.00        37
#
# ACCURACY: 100.0 %
#
# CONFUSION MATRIX:
# Predicted        Iris-setosa  Iris-versicolor  Iris-virginica  All
# True
# Iris-setosa               13                0               0   13
# Iris-versicolor            0                8               0    8
# Iris-virginica             0                0              16   16
# All                       13                8              16   37

# %%
data1.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
data1.species.unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
features = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width']
classifiers = ['Iris-setosa', 'Iris-versicolor', 'Iris-virginica']

from sklearn import tree

plt.figure(figsize=(30,15))
tree.plot_tree(dtm_clf, feature_names = features, class_names = classifiers, filled = True, rounded = True, label = 'all', node_ids = True, fontsize = 13)
plt.title('DECISION TREE DIAGRAM', fontdict = {'family': 'Verdana', 'color':  'darkgreen', 'style':'italic', 'size':'24'}, loc = 'center')
plt.show()

# %% [markdown]
# >  RANDOM FOREST ML MODEL.

# %%
from sklearn.ensemble import RandomForestClassifier

rfm_clf = RandomForestClassifier(random_state = 50, criterion = 'gini', n_estimators = 200)

rfm_clf.fit(X_train, y_train)
y_pred_rfm = rfm_clf.predict(X_test)

print('CLASSIFICATION REPORT:', '\n', classification_report(y_test,y_pred_rfm))
print('ACCURACY:', accuracy_score(y_test, y_pred_rfm)*100,'%')
print('')
print('CONFUSION MATRIX:')
pd.crosstab(y_test, y_pred_rfm, rownames=['True'], colnames=['Predicted'], margins=True)
# Out:
# CLASSIFICATION REPORT:
#                   precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        13
# Iris-versicolor       1.00      1.00      1.00         8
#  Iris-virginica       1.00      1.00      1.00        16
#
#        accuracy                           1.00        37
#       macro avg       1.00      1.00      1.00        37
#    weighted avg       1.00      1.00      1.00        37
#
# ACCURACY: 100.0 %
#
# CONFUSION MATRIX:
# Predicted        Iris-setosa  Iris-versicolor  Iris-virginica  All
# True
# Iris-setosa               13                0               0   13
# Iris-versicolor            0                8               0    8
# Iris-virginica             0                0              16   16
# All                       13                8              16   37

# %% [markdown]
#     INFERENCE.

# %%
print('-> Accuracy Percentage of LOGISTIC REGRESSION Model:-', accuracy_score(y_test, y_pred_lr)*100,'%')
print('-> Accuracy Percentageof KNN (Minkowski Distance Computation) Model:-', accuracy_score(y_test, y_pred_knn)*100,'%')
print('-> Accuracy Percentageof KNN (Canberra Distance Computation) Model:-', accuracy_score(y_test, y_pred_knn_1)*100,'%')
print('-> Accuracy Percentages for various SUPPORT VECTOR MACHINE Models:-')
print('\t =>SVM LINEAR KERNAL Model:-', accuracy_score(y_test, y_pred_svm1)*100,'%')
print('\t =>SVM RADIAL BASIS FUNCTION KERNAL Model:-', accuracy_score(y_test, y_pred_rbf)*100,'%')
print('\t =>SVM POLYNOMIAL KERNAL Model:-', accuracy_score(y_test, y_pred_p)*100,'%')
print('-> Accuracy Percentage of DECISION TREE Model:-', accuracy_score(y_test, y_pred_dtm)*100,'%')
print('-> Accuracy Percentage of RANDOM FOREST Model:-', accuracy_score(y_test, y_pred_rfm)*100,'%')
# Out:
# -> Accuracy Percentage of LOGISTIC REGRESSION Model:- 97.2972972972973 %
# -> Accuracy Percentageof KNN (Minkowski Distance Computation) Model:- 97.2972972972973 %
# -> Accuracy Percentageof KNN (Canberra Distance Computation) Model:- 94.5945945945946 %
# -> Accuracy Percentages for various SUPPORT VECTOR MACHINE Models:-
# 	 =>SVM LINEAR KERNAL Model:- 97.2972972972973 %
# 	 =>SVM RADIAL BASIS FUNCTION KERNAL Model:- 97.2972972972973 %
# 	 =>SVM POLYNOMIAL KERNAL Model:- 97.2972972972973 %
# -> Accuracy Percentage of DECISION TREE Model:- 100.0 %
# -> Accuracy Percentage of RANDOM FOREST Model:- 100.0 %
